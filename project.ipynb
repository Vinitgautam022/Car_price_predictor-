# %%
import pandas as pd 

import numpy as np

# %%
car = pd.read_csv("cleaned_Car_data.csv")

# %%
car.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                    name   company  \
# 0             0             0           0     Hyundai Santro Xing   Hyundai
# 1             1             1           1     Mahindra Jeep CL550  Mahindra
# 2             2             2           2       Hyundai Grand i10   Hyundai
# 3             3             3           3  Ford EcoSport Titanium      Ford
# 4             4             4           4               Ford Figo      Ford
#
#    year   Price  kms_driven fuel_type
# 0  2007   80000       45000    Petrol
# 1  2006  425000          40    Diesel
# 2  2014  325000       28000    Petrol
# 3  2014  575000       36000    Diesel
# 4  2012  175000       41000    Diesel

# %%
car['kms_driven']
# Out:
# 0       45000
# 1          40
# 2       28000
# 3       36000
# 4       41000
#         ...
# 811     50000
# 812     30000
# 813    132000
# 814     27000
# 815     40000
# Name: kms_driven, Length: 816, dtype: int64

# %%
car[~car['fuel_type'].isna()]
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                    name   company  \
# 0               0             0           0     Hyundai Santro Xing   Hyundai
# 1               1             1           1     Mahindra Jeep CL550  Mahindra
# 2               2             2           2       Hyundai Grand i10   Hyundai
# 3               3             3           3  Ford EcoSport Titanium      Ford
# 4               4             4           4               Ford Figo      Ford
# ..            ...           ...         ...                     ...       ...
# 811           811           811         811      Maruti Suzuki Ritz    Maruti
# 812           812           812         812          Tata Indica V2      Tata
# 813           813           813         813    Toyota Corolla Altis    Toyota
# 814           814           814         814            Tata Zest XM      Tata
# 815           815           815         815      Mahindra Quanto C8  Mahindra
#
#      year   Price  kms_driven fuel_type
# 0    2007   80000       45000    Petrol
# 1    2006  425000          40    Diesel
# 2    2014  325000       28000    Petrol
# 3    2014  575000       36000    Diesel
# 4    2012  175000       41000    Diesel
# ..    ...     ...         ...       ...
# 811  2011  270000       50000    Petrol
# 812  2009  110000       30000    Diesel
# 813  2009  300000      132000    Petrol
# 814  2018  260000       27000    Diesel
# 815  2013  390000       40000    Diesel
#
# [816 rows x 9 columns]

# %%
car.describe()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0         year         Price  \
# count    816.000000    816.000000  816.000000   816.000000  8.160000e+02
# mean     407.500000    407.500000  407.500000  2012.444853  4.117176e+05
# std      235.703203    235.703203  235.703203     4.002992  4.751844e+05
# min        0.000000      0.000000    0.000000  1995.000000  3.000000e+04
# 25%      203.750000    203.750000  203.750000  2010.000000  1.750000e+05
# 50%      407.500000    407.500000  407.500000  2013.000000  2.999990e+05
# 75%      611.250000    611.250000  611.250000  2015.000000  4.912500e+05
# max      815.000000    815.000000  815.000000  2019.000000  8.500003e+06
#
#           kms_driven
# count     816.000000
# mean    46275.531863
# std     34297.428044
# min         0.000000
# 25%     27000.000000
# 50%     41000.000000
# 75%     56818.500000
# max    400000.000000

# %%
car = car[car['Price'] < 6e6].reset_index(drop=True)
car
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                    name   company  \
# 0               0             0           0     Hyundai Santro Xing   Hyundai
# 1               1             1           1     Mahindra Jeep CL550  Mahindra
# 2               2             2           2       Hyundai Grand i10   Hyundai
# 3               3             3           3  Ford EcoSport Titanium      Ford
# 4               4             4           4               Ford Figo      Ford
# ..            ...           ...         ...                     ...       ...
# 810           811           811         811      Maruti Suzuki Ritz    Maruti
# 811           812           812         812          Tata Indica V2      Tata
# 812           813           813         813    Toyota Corolla Altis    Toyota
# 813           814           814         814            Tata Zest XM      Tata
# 814           815           815         815      Mahindra Quanto C8  Mahindra
#
#      year   Price  kms_driven fuel_type
# 0    2007   80000       45000    Petrol
# 1    2006  425000          40    Diesel
# 2    2014  325000       28000    Petrol
# 3    2014  575000       36000    Diesel
# 4    2012  175000       41000    Diesel
# ..    ...     ...         ...       ...
# 810  2011  270000       50000    Petrol
# 811  2009  110000       30000    Diesel
# 812  2009  300000      132000    Petrol
# 813  2018  260000       27000    Diesel
# 814  2013  390000       40000    Diesel
#
# [815 rows x 9 columns]

# %%
x=car.drop(columns='Price')
y=car['Price']

# %%
x
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                    name   company  \
# 0               0             0           0     Hyundai Santro Xing   Hyundai
# 1               1             1           1     Mahindra Jeep CL550  Mahindra
# 2               2             2           2       Hyundai Grand i10   Hyundai
# 3               3             3           3  Ford EcoSport Titanium      Ford
# 4               4             4           4               Ford Figo      Ford
# ..            ...           ...         ...                     ...       ...
# 810           811           811         811      Maruti Suzuki Ritz    Maruti
# 811           812           812         812          Tata Indica V2      Tata
# 812           813           813         813    Toyota Corolla Altis    Toyota
# 813           814           814         814            Tata Zest XM      Tata
# 814           815           815         815      Mahindra Quanto C8  Mahindra
#
#      year  kms_driven fuel_type
# 0    2007       45000    Petrol
# 1    2006          40    Diesel
# 2    2014       28000    Petrol
# 3    2014       36000    Diesel
# 4    2012       41000    Diesel
# ..    ...         ...       ...
# 810  2011       50000    Petrol
# 811  2009       30000    Diesel
# 812  2009      132000    Petrol
# 813  2018       27000    Diesel
# 814  2013       40000    Diesel
#
# [815 rows x 8 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 810    270000
# 811    110000
# 812    300000
# 813    260000
# 814    390000
# Name: Price, Length: 815, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
OneHotEncoder()
# Out:
# OneHotEncoder()

# %%
x_train
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                 name    company  \
# 210           210           210         210    Maruti Suzuki SX4     Maruti
# 675           676           676         676  Maruti Suzuki Wagon     Maruti
# 699           700           700         700   Hyundai i10 Sportz    Hyundai
# 32             32            32          32  Maruti Suzuki Wagon     Maruti
# 702           703           703         703       Honda City 1.5      Honda
# ..            ...           ...         ...                  ...        ...
# 377           377           377         377  Maruti Suzuki Swift     Maruti
# 349           349           349         349   Chevrolet Spark LT  Chevrolet
# 93             93            93          93     Ford Figo Diesel       Ford
# 33             33            33          33    Toyota Innova 2.0     Toyota
# 363           363           363         363   Maruti Suzuki Alto     Maruti
#
#      year  kms_driven fuel_type
# 210  2012       46000    Diesel
# 675  2014       37458    Petrol
# 699  2011       38000    Petrol
# 32   2013       39000    Petrol
# 702  2005       41000    Petrol
# ..    ...         ...       ...
# 377  2012       40000    Petrol
# 349  2009       44000    Petrol
# 93   2012       35000    Diesel
# 33   2012       82000    Diesel
# 363  2015        5000    Petrol
#
# [652 rows x 8 columns]

# %%
ohe=OneHotEncoder()
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr= LinearRegression()
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# c:\Users\vinit\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(x_test)
y_pred
# Out:
# array([ 420916.86869017, -155676.61683904,  -35382.73677621,
#         266359.88930034,  414948.50918062,  165281.67074189,
#         261959.02014532,  597944.1300751 ,  426174.01052345,
#         298205.65121517,  341336.16123985,  512645.34270793,
#          90097.64423455,  528007.89926223,  131578.74570681,
#         117917.22041912,  219444.80695282,  -43354.83751458,
#         438070.86961124,  265589.14907316,  547226.97434973,
#         236919.86033883,  546759.93293421,  356298.5414351 ,
#        1092832.6407103 ,  686961.68962105,  363406.73593283,
#         157398.68278729,  210654.27029209,  477295.22046322,
#         465079.01288629,  598233.34163515,  576850.42098212,
#        1446621.29519831,  270926.95749977,  461254.57876647,
#         313293.88239976,  383753.16191474,  287085.27094727,
#         224514.23722174,  455937.6992493 ,  366925.51954452,
#         278680.30044185,  381131.20279068,  322151.71654169,
#         382248.02452868,  420800.11050677,  244435.4609728 ,
#         467063.94294977,  320873.2847496 ,  217439.0984349 ,
#         306397.54816379,  340361.83665804,  306747.46213426,
#         247783.87593392,  148506.90116647,  118654.71156755,
#         444067.62298242,  699601.79133425,  785142.89733167,
#         348370.38387678,   99583.9347852 ,  237288.23018581,
#         544628.95463999,  135350.46439985,  407411.11270356,
#         246615.70490947,  304747.80572227,  367859.46721002,
#         577524.06020664,  422125.35453557,  618082.29014866,
#          81639.74063678,  290216.22171523,  641995.41520435,
#         211817.25838734,  647547.06645838,  224140.66139772,
#         121401.32551353,  463241.98509964, 1498811.24867608,
#         352777.2272091 ,  208150.13500088,  880483.16816396,
#         483956.76670212, 1006090.46490606,  315298.25066642,
#         314861.41956977,  417971.85032332,  495663.43060719,
#         618800.39140243,  407718.33974367,  826297.81910062,
#         137145.52658033,  349125.80137779,  405045.73962267,
#         249065.576418  ,  452993.42190591,  626298.56423618,
#          39408.14374594,  451960.80280301, 1495436.4970126 ,
#         165673.65729301,  164236.84795069,   90881.31296868,
#         418058.82431392,  417254.13921374,  445414.90408237,
#         178685.01771266,  192722.21096994,  273945.04593144,
#         294066.08049884,  427894.60134995,  621029.09893748,
#         253659.58518178,  260391.08773135,  470628.26317783,
#         286128.70979568,  252106.83643566,  313433.92486954,
#         685254.6749221 ,   86014.77157183,  510070.37627733,
#         560201.27817702,  721290.14890152,  160683.22204925,
#         403711.42717147,  359824.27623014,  306862.41714858,
#         313660.54046702,  782026.34011916,  404301.40177478,
#         648739.75546286,  485323.45569314,  360569.42666285,
#         447386.94406954,  382588.45796058,  514639.45729996,
#         512456.46185504,  783396.56435228,  297503.81775345,
#         667986.32660971,  213430.48286337,  319893.0762547 ,
#         272408.16145429,  575965.67811386,  608264.23076215,
#         457787.79958146,  129882.69297969,  273591.97172459,
#         716110.01390928,  326938.54854392,  447853.76017452,
#         156654.10256337,  369911.56874172,  427703.36905386,
#         132342.55278473,  713325.99898066,  414500.97546885,
#         251413.86312618,  417617.11871531,  350356.15504754,
#         347661.10132345])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5707829699018234

# %%
scores=[]
for i in range(10):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    print(r2_score(y_test,y_pred),i)
# Out:
# 0.7160746752904379 0
# 0.6132865494253271 1
# 0.5494992870161843 2
# 0.6811814805509471 3
# 0.8254226000464107 4
# 0.6203605531840706 5
# 0.7775925302547735 6
# 0.6659250556283077 7
# 0.7465474028585459 8
# 0.6502391792341072 9

# %%
np.argmax(scores )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 np.argmax(scores )
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:56, in _wrapfunc(obj, method, *args, **kwds)
#      54 bound = getattr(obj, method, None)
#      55 if bound is None:
# ---> 56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
#      59     return bound(*args, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# ValueError: attempt to get argmax of an empty sequence

# %%
scores[np.argmax(scores)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 scores[np.argmax(scores)]
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:56, in _wrapfunc(obj, method, *args, **kwds)
#      54 bound = getattr(obj, method, None)
#      55 if bound is None:
# ---> 56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
#      59     return bound(*args, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# ValueError: attempt to get argmax of an empty sequence

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=np.argmax(scores))
#       2 lr=LinearRegression()
#       3 pipe=make_pipeline(column_trans,lr)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:56, in _wrapfunc(obj, method, *args, **kwds)
#      54 bound = getattr(obj, method, None)
#      55 if bound is None:
# ---> 56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
#      59     return bound(*args, **kwds)
#
# File c:\Users\vinit\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# ValueError: attempt to get argmax of an empty sequence
